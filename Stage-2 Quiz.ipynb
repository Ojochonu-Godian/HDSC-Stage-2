# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('energydata_complete.csv')

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
simple_Linear_reg_df = df[['T2','T6']].sample(15, random_state = 2)

# %%
print(simple_Linear_reg_df)
# Out:
#               T2         T6
# 1117   17.426667  -4.238889
# 16275  22.760000  14.690000
# 13272  21.230000   8.926667
# 3160   21.100000   7.690000
# 19210  21.856667  10.800000
# 8260   17.356667   5.000000
# 12299  19.000000   5.300000
# 13505  22.700000  17.133333
# 12913  19.593333   7.545000
# 17788  21.890000   9.190000
# 17894  21.500000   5.160000
# 7665   19.142857   0.937500
# 10165  18.000000   0.200000
# 18809  22.400000  16.833333
# 8737   17.066667   1.900000

# %%
sns.regplot(x='T2', y= 'T6', data=simple_Linear_reg_df, color = 'g')
# Out:
# <AxesSubplot:xlabel='T2', ylabel='T6'>

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 from sklearn.metrics import r2_score
# ----> 2 r2_score = r2_score(y_test, predicted_values)
#       3 round(r2_score, 3)
#
# NameError: name 'y_test' is not defined

# %%
data = df.drop('date', axis =1)

# %%
data = df.drop('lights', axis =1)

# %%
data.head()
# Out:
#                   date  Appliances     T1       RH_1    T2       RH_2     T3  \
# 0  2016-01-11 17:00:00          60  19.89  47.596667  19.2  44.790000  19.79
# 1  2016-01-11 17:10:00          60  19.89  46.693333  19.2  44.722500  19.79
# 2  2016-01-11 17:20:00          50  19.89  46.300000  19.2  44.626667  19.79
# 3  2016-01-11 17:30:00          50  19.89  46.066667  19.2  44.590000  19.79
# 4  2016-01-11 17:40:00          60  19.89  46.333333  19.2  44.530000  19.79
#
#         RH_3         T4       RH_4  ...         T9   RH_9     T_out  \
# 0  44.730000  19.000000  45.566667  ...  17.033333  45.53  6.600000
# 1  44.790000  19.000000  45.992500  ...  17.066667  45.56  6.483333
# 2  44.933333  18.926667  45.890000  ...  17.000000  45.50  6.366667
# 3  45.000000  18.890000  45.723333  ...  17.000000  45.40  6.250000
# 4  45.000000  18.890000  45.530000  ...  17.000000  45.40  6.133333
#
#    Press_mm_hg  RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0        733.5    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1        733.6    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2        733.7    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3        733.8    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4        733.9    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 28 columns]

# %%
data = df.drop('date' , axis = 1)

# %%
data.head()
# Out:
#    Appliances  lights     T1       RH_1    T2       RH_2     T3       RH_3  \
# 0          60      30  19.89  47.596667  19.2  44.790000  19.79  44.730000
# 1          60      30  19.89  46.693333  19.2  44.722500  19.79  44.790000
# 2          50      30  19.89  46.300000  19.2  44.626667  19.79  44.933333
# 3          50      40  19.89  46.066667  19.2  44.590000  19.79  45.000000
# 4          60      40  19.89  46.333333  19.2  44.530000  19.79  45.000000
#
#           T4       RH_4  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  19.000000  45.566667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  19.000000  45.992500  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  18.926667  45.890000  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  18.890000  45.723333  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  18.890000  45.530000  ...  17.000000  45.40  6.133333        733.9    92.0
#
#    Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0   7.000000   63.000000        5.3  13.275433  13.275433
# 1   6.666667   59.166667        5.2  18.606195  18.606195
# 2   6.333333   55.333333        5.1  28.642668  28.642668
# 3   6.000000   51.500000        5.0  45.410389  45.410389
# 4   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 28 columns]

# %%
df1 = data.drop('lights', axis = 1)

# %%
df1.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
#    Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0   7.000000   63.000000        5.3  13.275433  13.275433
# 1   6.666667   59.166667        5.2  18.606195  18.606195
# 2   6.333333   55.333333        5.1  28.642668  28.642668
# 3   6.000000   51.500000        5.0  45.410389  45.410389
# 4   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 27 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(df1), columns = df1.columns)
features_df = normalised_df.drop(columns = ['Appliances'])
target_variable = normalised_df['Appliances']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features_df, target_variable, test_size = 0.3, random_state =42)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
linear_model.fit(x_train,y_train)
predicted_values = linear_model.predict(x_test)

# %% [markdown]
# ### Mean Absolute Error (MAE)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test,predicted_values)
round(mae,2)
# Out:
# 0.05

# %% [markdown]
# ### Residual Sum Of Square (RSS)

# %%
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 2)
# Out:
# 45.35

# %% [markdown]
# ### Root Mean Square Error (RMSE)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,predicted_values))
round(rmse,3)
# Out:
# 0.088

# %% [markdown]
# ### Coefficient of Determination (R-Squared)

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 2)
# Out:
# 0.15

# %% [markdown]
# ### Ridge penalization

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %% [markdown]
# ### Lasso penalization

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
def get_weights_df(model, feat, col_name):
    #this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Rigde_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'lasso_weight')

final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')

# %%
final_weights
# Out:
#        Features  Linear_Model_Weight  Rigde_Weight  lasso_weight
# 0           rv1        -1.199400e+11      0.000743     -0.000000
# 1          RH_2        -4.569467e-01     -0.401134     -0.000000
# 2         T_out        -3.219377e-01     -0.250765      0.000000
# 3            T2        -2.363617e-01     -0.193880      0.000000
# 4            T9        -1.899346e-01     -0.188584     -0.000000
# 5          RH_8        -1.576305e-01     -0.156596     -0.000110
# 6        RH_out        -7.769361e-02     -0.050541     -0.049557
# 7          RH_7        -4.455710e-02     -0.046291     -0.000000
# 8          RH_9        -3.981882e-02     -0.041701     -0.000000
# 9            T5        -1.564789e-02     -0.020727     -0.000000
# 10           T1        -3.281051e-03     -0.021549      0.000000
# 11  Press_mm_hg         6.874983e-03      0.006516     -0.000000
# 12           T7         1.030306e-02      0.010021     -0.000000
# 13   Visibility         1.228827e-02      0.012032      0.000000
# 14         RH_5         1.603044e-02      0.016176      0.000000
# 15         RH_4         2.639802e-02      0.024168      0.000000
# 16           T4         2.898319e-02      0.027006     -0.000000
# 17    Windspeed         2.919986e-02      0.030463      0.002912
# 18         RH_6         3.807195e-02      0.035023     -0.000000
# 19         RH_3         9.609626e-02      0.094976      0.000000
# 20           T8         1.020212e-01      0.100754      0.000000
# 21    Tdewpoint         1.178136e-01      0.076668      0.000000
# 22           T6         2.364848e-01      0.213316      0.000000
# 23           T3         2.907524e-01      0.287408      0.000000
# 24         RH_1         5.536009e-01      0.511932      0.017880
# 25          rv2         1.199400e+11      0.000743     -0.000000

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,predicted_values))
round(rmse,3)
# Out:
# 0.088
